# %% [markdown]
# # Item-Based Memory Model

# %%
import numpy as np
import pandas as pd
from scipy import spatial
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# Read in the data into a dataframe:

# %%
ratings = pd.read_csv('./ml-100k/u.data', sep='\t', header=None)
ratings.columns = ['user_id', 'movie_id', 'rating', 'timestamp']
movie_titles = pd.read_csv('./ml-100k/u.item', sep='|', header=None, encoding="ISO-8859-1")
movie_titles.columns = """movie_id | movie_title | release_date | video_release_date |
              IMDb URL | unknown | Action | Adventure | Animation |
              Childrens | Comedy | Crime | Documentary | Drama | Fantasy |
              Film-Noir | Horror | Musical | Mystery | Romance | Sci-Fi |
              Thriller | War | Western""".replace('\n', '').replace(' ', '').split('|')

# %%
ratings = pd.merge(ratings, movie_titles[['movie_id', 'movie_title']], left_on='movie_id', right_on='movie_id')
ratings
# Out:
#        user_id  movie_id  rating  timestamp  \
# 0          196       242       3  881250949
# 1           63       242       3  875747190
# 2          226       242       5  883888671
# 3          154       242       3  879138235
# 4          306       242       5  876503793
# ...        ...       ...     ...        ...
# 99995      840      1674       4  891211682
# 99996      655      1640       3  888474646
# 99997      655      1637       3  888984255
# 99998      655      1630       3  887428735
# 99999      655      1641       3  887427810
#
#                                              movie_title
# 0                                           Kolya (1996)
# 1                                           Kolya (1996)
# 2                                           Kolya (1996)
# 3                                           Kolya (1996)
# 4                                           Kolya (1996)
# ...                                                  ...
# 99995                                  Mamma Roma (1962)
# 99996                             Eighth Day, The (1996)
# 99997                                  Girls Town (1996)
# 99998  Silence of the Palace, The (Saimt el Qusur) (1...
# 99999                                    Dadetown (1995)
#
# [100000 rows x 5 columns]

# %%
np.unique(ratings.movie_id).shape
# Out:
# (1682,)

# %% [markdown]
# Create a user-item matrix where rows are users and columns are items. Empty cell are filled with `nan`

# %%
user_item_matrix = np.empty((np.unique(ratings.user_id).shape[0], np.unique(ratings.movie_id).shape[0]))
user_item_matrix[:] = np.nan
user_item_matrix
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])

# %%
for row in ratings.iterrows():
    row_index, row = row
    user_item_matrix[row['user_id'] - 1, row['movie_id'] - 1] = int(row['rating'])

# %%
user_item_matrix
# Out:
# array([[ 5.,  3.,  4., ..., nan, nan, nan],
#        [ 4., nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [ 5., nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan,  5., nan, ..., nan, nan, nan]])

# %% [markdown]
# Normalise the ratings by calculating the average rating for each user and subtracting it from their respective ratings

# %%
def normalise(array: np.array) -> np.array:
    rating_idx = np.argwhere(~np.isnan(array))
    ratings = array[rating_idx]
    ratings = ratings - np.mean(ratings)
    array[rating_idx] = ratings
    return array

# %%
user_item_matrix_norm = np.apply_along_axis(normalise, 1, np.copy(user_item_matrix))

# %%
user_item_matrix_norm
# Out:
# array([[ 1.38970588, -0.61029412,  0.38970588, ...,         nan,
#                 nan,         nan],
#        [ 0.29032258,         nan,         nan, ...,         nan,
#                 nan,         nan],
#        [        nan,         nan,         nan, ...,         nan,
#                 nan,         nan],
#        ...,
#        [ 0.95454545,         nan,         nan, ...,         nan,
#                 nan,         nan],
#        [        nan,         nan,         nan, ...,         nan,
#                 nan,         nan],
#        [        nan,  1.58928571,         nan, ...,         nan,
#                 nan,         nan]])

# %% [markdown]
# Create a similarity matrix between items.

# %%
sim_matrix = np.zeros((user_item_matrix.shape[1], user_item_matrix.shape[1]))

# %%
for i1 in range(user_item_matrix_norm.shape[1]):
    i1_array = user_item_matrix_norm[:,i1]
    for i2 in range(user_item_matrix_norm.shape[1]):
        if i1 != i2:
            i2_array = user_item_matrix_norm[:,i2]
            col_cat = np.array([i1_array, i2_array])
            col_cat = col_cat[:, ~np.isnan(col_cat).any(axis=0)]

            if col_cat.size != 0:
                sim = cosine_similarity([col_cat[0,]], [col_cat[1,]]).flat[0]
                sim_matrix[i1, i2] = sim
            else:
                sim_matrix[i1, i2] = 0
        else:
            sim_matrix[i1, i2] = 1
    
    if i1% 100 == 0:
        print(i1)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600

# %%
sim_matrix.shape
# Out:
# (1682, 1682)

# %%
# Make a prediction for a given user_id and item_id
# Note user ids and item ids are offset by -1 so they start at zero index
def predict(user_id, item_id):
    sim_scores = sim_matrix[item_id, ]
    sim_items = np.argsort(sim_scores)[::-1][:20]
    sim_items = np.array([i for i in sim_items if i != item_id])
    mask = ~np.isnan(user_item_matrix[user_id, sim_items])
    user_ratings = user_item_matrix[user_id, sim_items][mask]

    pred = np.sum(user_ratings * sim_scores[sim_items][mask]) / np.sum(sim_scores[sim_items][mask])
    
    print(pred)

# %%
predict(3, 3)
# Out:
# 5.0

# %%
ratings[ratings.user_id == 4].sort_values('rating', ascending=False).head(20)
# Out:
#        user_id  movie_id  rating  timestamp  \
# 6518         4       327       5  892002352
# 37023        4       303       5  892002352
# 92411        4       359       5  892002352
# 89023        4       329       5  892002352
# 85076        4       361       5  892002353
# 76276        4       300       5  892001445
# 69761        4       354       5  892002353
# 64690        4       324       5  892002353
# 56372        4       301       5  892002353
# 50790        4        50       5  892003526
# 27030        4       360       5  892002352
# 25189        4       258       5  892001374
# 15160        4       294       5  892004409
# 93971        4       362       5  892002352
# 40214        4       271       4  892001690
# 9896         4       288       4  892001445
# 36411        4       357       4  892003525
# 35055        4        11       4  892004520
# 85133        4       260       4  892004275
# 49322        4       210       3  892003374
#
#                                      movie_title
# 6518                             Cop Land (1997)
# 37023                         Ulee's Gold (1997)
# 92411                     Assignment, The (1997)
# 89023                  Desperate Measures (1998)
# 85076                           Incognito (1997)
# 76276                       Air Force One (1997)
# 69761                 Wedding Singer, The (1998)
# 64690                        Lost Highway (1997)
# 56372                            In & Out (1997)
# 50790                           Star Wars (1977)
# 27030                          Wonderland (1997)
# 25189                             Contact (1997)
# 15160                           Liar Liar (1997)
# 93971                 Blues Brothers 2000 (1998)
# 40214                   Starship Troopers (1997)
# 9896                               Scream (1996)
# 36411     One Flew Over the Cuckoo's Nest (1975)
# 35055                       Seven (Se7en) (1995)
# 85133                       Event Horizon (1997)
# 49322  Indiana Jones and the Last Crusade (1989)

# %%
# Here the movie ID is that of the movie lens data set
# e.g. Toy story movie id = 1
def get_similar_movies(movie_id):
    sim_movies = np.argsort(sim_matrix[movie_id - 1, ])[::-1][:10]
    for s in sim_movies:
        print(movie_titles[movie_titles.movie_id == s+1].movie_title.values[0])

# %%
# Star Trek: First Contact (1996)
get_similar_movies(222)
# Out:
# That Old Feeling (1997)
# Scream of Stone (Schrei aus Stein) (1991)
# Love Is All There Is (1996)
# Angela (1995)
# Last Summer in the Hamptons (1995)
# Truth or Consequences, N.M. (1997)
# Intimate Relations (1996)
# Beyond Bedlam (1993)
# Here Comes Cookie (1935)
# Reluctant Debutante, The (1958)

# %%
# Toy Story
get_similar_movies(1)
# Out:
# Toy Story (1995)
# Visitors, The (Visiteurs, Les) (1993)
# Stars Fell on Henrietta, The (1995)
# Here Comes Cookie (1935)
# Sleepover (1995)
# Shopping (1994)
# Nemesis 2: Nebula (1995)
# Beyond Bedlam (1993)
# Relative Fear (1994)
# Love Is All There Is (1996)

# %%
# Star Wars
get_similar_movies(50)
# Out:
# Bitter Sugar (Azucar Amargo) (1996)
# Two Friends (1986)
# Savage Nights (Nuits fauves, Les) (1992)
# Boys, Les (1997)
# Hana-bi (1997)
# Men With Guns (1997)
# Butcher Boy, The (1998)
# He Walked by Night (1948)
# I Don't Want to Talk About It (De eso no se habla) (1993)
# Some Mother's Son (1996)

# %%
movie_titles[movie_titles.movie_id == 862+1]
# Out:
#      movie_id                                        movie_title release_date  \
# 862       863  Garden of Finzi-Contini, The (Giardino dei Fin...  08-Nov-1996
#
#      video_release_date                                            IMDbURL  \
# 862                 NaN  http://us.imdb.com/M/title-exact?Giardino%20de...
#
#      unknown  Action  Adventure  Animation  Childrens  ...  Fantasy  \
# 862        0       0          0          0          0  ...        0
#
#      Film-Noir  Horror  Musical  Mystery  Romance  Sci-Fi  Thriller  War  \
# 862          0       0        0        0        0       0         0    0
#
#      Western
# 862        0
#
# [1 rows x 24 columns]

# %%
movie_titles[movie_titles.movie_title.str.contains('Star')]
# Out:
#       movie_id                                     movie_title release_date  \
# 49          50                                Star Wars (1977)  01-Jan-1977
# 61          62                                 Stargate (1994)  01-Jan-1994
# 123        124                                Lone Star (1996)  21-Jun-1996
# 145        146                         Unhook the Stars (1996)  30-Oct-1996
# 221        222                 Star Trek: First Contact (1996)  22-Nov-1996
# 226        227   Star Trek VI: The Undiscovered Country (1991)  01-Jan-1991
# 227        228             Star Trek: The Wrath of Khan (1982)  01-Jan-1982
# 228        229      Star Trek III: The Search for Spock (1984)  01-Jan-1984
# 229        230            Star Trek IV: The Voyage Home (1986)  01-Jan-1986
# 270        271                        Starship Troopers (1997)  01-Jan-1997
# 379        380                   Star Trek: Generations (1994)  01-Jan-1994
# 448        449            Star Trek: The Motion Picture (1979)  01-Jan-1979
# 449        450          Star Trek V: The Final Frontier (1989)  01-Jan-1989
# 1060      1061                        Evening Star, The (1996)  25-Dec-1996
# 1067      1068  Star Maker, The (Uomo delle stelle, L') (1995)  01-Mar-1996
# 1264      1265                                Star Maps (1997)  01-Jan-1997
# 1292      1293                                 Star Kid (1997)  16-Jan-1998
# 1463      1464             Stars Fell on Henrietta, The (1995)  01-Jan-1995
# 1544      1545                        Frankie Starlight (1995)  01-Jan-1995
#
#       video_release_date                                            IMDbURL  \
# 49                   NaN  http://us.imdb.com/M/title-exact?Star%20Wars%2...
# 61                   NaN  http://us.imdb.com/M/title-exact?Stargate%20(1...
# 123                  NaN  http://us.imdb.com/M/title-exact?Lone%20Star%2...
# 145                  NaN  http://us.imdb.com/M/title-exact?Unhook%20the%...
# 221                  NaN  http://us.imdb.com/M/title-exact?Star%20Trek:%...
# 226                  NaN  http://us.imdb.com/M/title-exact?Star%20Trek%2...
# 227                  NaN  http://us.imdb.com/M/title-exact?Star%20Trek:%...
# 228                  NaN  http://us.imdb.com/M/title-exact?Star%20Trek%2...
# 229                  NaN  http://us.imdb.com/M/title-exact?Star%20Trek%2...
# 270                  NaN  http://us.imdb.com/M/title-exact?Starship+Troo...
# 379                  NaN  http://us.imdb.com/M/title-exact?Star%20Trek:%...
# 448                  NaN  http://us.imdb.com/M/title-exact?Star%20Trek:%...
# 449                  NaN  http://us.imdb.com/M/title-exact?Star%20Trek%2...
# 1060                 NaN  http://us.imdb.com/M/title-exact?Evening%20Sta...
# 1067                 NaN  http://us.imdb.com/M/title-exact?Uomo%20delle%...
# 1264                 NaN  http://us.imdb.com/M/title-exact?Star+Maps+(1997)
# 1292                 NaN  http://us.imdb.com/M/title-exact?imdb-title-12...
# 1463                 NaN  http://us.imdb.com/Title?Stars+Fell+on+Henriet...
# 1544                 NaN  http://us.imdb.com/M/title-exact?Frankie%20Sta...
#
#       unknown  Action  Adventure  Animation  Childrens  ...  Fantasy  \
# 49          0       1          1          0          0  ...        0
# 61          0       1          1          0          0  ...        0
# 123         0       0          0          0          0  ...        0
# 145         0       0          0          0          0  ...        0
# 221         0       1          1          0          0  ...        0
# 226         0       1          1          0          0  ...        0
# 227         0       1          1          0          0  ...        0
# 228         0       1          1          0          0  ...        0
# 229         0       1          1          0          0  ...        0
# 270         0       1          1          0          0  ...        0
# 379         0       1          1          0          0  ...        0
# 448         0       1          1          0          0  ...        0
# 449         0       1          1          0          0  ...        0
# 1060        0       0          0          0          0  ...        0
# 1067        0       0          0          0          0  ...        0
# 1264        0       0          0          0          0  ...        0
# 1292        0       0          1          0          1  ...        1
# 1463        0       0          0          0          0  ...        0
# 1544        0       0          0          0          0  ...        0
#
#       Film-Noir  Horror  Musical  Mystery  Romance  Sci-Fi  Thriller  War  \
# 49            0       0        0        0        1       1         0    1
# 61            0       0        0        0        0       1         0    0
# 123           0       0        0        1        0       0         0    0
# 145           0       0        0        0        0       0         0    0
# 221           0       0        0        0        0       1         0    0
# 226           0       0        0        0        0       1         0    0
# 227           0       0        0        0        0       1         0    0
# 228           0       0        0        0        0       1         0    0
# 229           0       0        0        0        0       1         0    0
# 270           0       0        0        0        0       1         0    1
# 379           0       0        0        0        0       1         0    0
# 448           0       0        0        0        0       1         0    0
# 449           0       0        0        0        0       1         0    0
# 1060          0       0        0        0        0       0         0    0
# 1067          0       0        0        0        0       0         0    0
# 1264          0       0        0        0        0       0         0    0
# 1292          0       0        0        0        0       1         0    0
# 1463          0       0        0        0        0       0         0    0
# 1544          0       0        0        0        1       0         0    0
#
#       Western
# 49          0
# 61          0
# 123         0
# 145         0
# 221         0
# 226         0
# 227         0
# 228         0
# 229         0
# 270         0
# 379         0
# 448         0
# 449         0
# 1060        0
# 1067        0
# 1264        0
# 1292        0
# 1463        0
# 1544        0
#
# [19 rows x 24 columns]
